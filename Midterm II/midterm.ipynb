# %% [markdown]
#  ## Parcial II - Estructuras de Datos
# ---
#
# -Juan Pablo Madriz-
# -20240841-

# %% [markdown]
# ### **Instrucciones:**
#
# Desarrolle su parcial en este notebook según las indicaciones en las siguientes celdas. Trabaje de forma ordenada y asegúrese que el notebook corra exitosamente antes de entregarlo (`clear all outputs` -> `restart` kernel -> `run all`). De esta misma manera se calificará su parcial. Un notebook que presente problemas en el `run all` será considerado inválido.

# %% [markdown]
# #### **1 - Binary Search Tree**
# ---
#
# 1.1 - En el archivo `bst.py`, agregue la clase de BST desarrollada en clase. Asegúrese de incluir el método *pretty_print()*.
#
# 1.2 - Instanciar un BST y agregar 25 elementos cualesquiera. Luego, demostrar que las operaciones de *insert()*, *delete()* y *search()* funcionan como esperado en un Binary Search Tree. Dejar constancia de cada una de estas operaciones con el método *pretty_print()*.

# %%
from bst import BinarySearchTree
tree = BinarySearchTree()

# %%
vals = [40, 25, 34, 15, 60, 30, 10, 20, 75, 55,
5, 12, 28, 36, 32, 81, 72, 68, 45, 18,
62, 58, 48, 7, 93
] # arbol original
for val in vals:
    tree.insert(val)
tree.print_pretty()
# Out:
#               __________40_________
#              /                     \
#         ____25_______           __60_______
#        /             \         /           \
#     __15___       __34_     __55_         75_
#    /       \     /     \   /     \       /   \
#  _10_     20    30_   36  45_   58      72  81_
# /    \   /     /   \         \         /       \
# 5   12  18    28  32        48        68      93
#  \                                   /
#  7                                  62

# %%
print("\nAgregar dato")
tree.insert(191)
tree.print_pretty()
# Out:
# Agregar dato
#
#               __________40_________
#              /                     \
#         ____25_______           __60_______
#        /             \         /           \
#     __15___       __34_     __55_         75_
#    /       \     /     \   /     \       /   \
#  _10_     20    30_   36  45_   58      72  81_
# /    \   /     /   \         \         /       \
# 5   12  18    28  32        48        68      93_
#  \                                   /           \
#  7                                  62          191

# %%
print("\nEliminar dato")
tree.delete(68)
tree.print_pretty()
# Out:
# Eliminar dato
# Deleting node with value 68.
#
#               __________40_________
#              /                     \
#         ____25_______           __60_____
#        /             \         /         \
#     __15___       __34_     __55_       75_
#    /       \     /     \   /     \     /   \
#  _10_     20    30_   36  45_   58    72  81_
# /    \   /     /   \         \       /       \
# 5   12  18    28  32        48      62      93_
#  \                                             \
#  7                                            191

# %%
print("\nBuscar dato")
print(tree.search(10))
tree.print_pretty()
# Out:
# Buscar dato
# True
#
#               __________40_________
#              /                     \
#         ____25_______           __60_____
#        /             \         /         \
#     __15___       __34_     __55_       75_
#    /       \     /     \   /     \     /   \
#  _10_     20    30_   36  45_   58    72  81_
# /    \   /     /   \         \       /       \
# 5   12  18    28  32        48      62      93_
#  \                                             \
#  7                                            191

# %% [markdown]
# #### **2 - AVL Tree**
# ---
#
# 2.1 - En el archivo `avl.py`, crear una clase que implemente un árbol AVL. Esta clase puede ser implementada desde cero o generada con AI. Considerar que:
# - La clase debe estar explícitamente declarada en el `avl.py`, ya que debe incluir el método de *pretty_print()*. Esto imposibilita el uso de alguna librería de python que contenga una implementación de AVL.
# - Si utiliza AI para generar la clase, debe documentar en este notebook el prompt utilizado, ya sea en las celdas correspondientes al inciso o en un apartado de Anexos.
#
# 2.2 - Instanciar un AVL y agregar 25 elementos cualesquiera. Luego, demostrar que las operaciones de *insert()*, *delete()* y *search()* funcionan como esperado en un árbol AVL. Dejar constancia de cada una de estas operaciones con el método *pretty_print()*.

# %%
# Prompts de AI para implementar el AVL
# hola necesito que ma hagas un codigo como el que te voy a mandar. 
# El codigo que te voy a mandar es un binary search tree, y necesito 
# que el codigo que me proporciones me lo cambies a un AVL que es un Binary search tree pero autobalanceado
# Pego el codigo en AI
# El codigo AVL que me propociones necesito que tenga las misma funciones que el BST como 
# insert(), delete(), search(), lo que necesito es que implementes la logica AVL
# Ahora necesito que me proporciones el codigo  y la clase debe de estar declarada com avl.py

# %%
from avl import AVLTree
tree = AVLTree()

# %%
vals = [40, 25, 34, 15, 60, 30, 10, 20, 75, 55,
5, 12, 28, 36, 32, 81, 72, 68, 45, 18,
62, 58, 48, 7, 93
] # arbol original
for val in vals:
    tree.insert(val)
tree.print_pretty()
# Out:
#         ____________34_____________
#        /                           \
#     __15_____               ______60_______
#    /         \             /               \
#  _10_       25___         45___         __75_
# /    \     /     \       /     \       /     \
# 5   12    20    30_     40    55_     68_   81_
#  \       /     /   \   /     /   \   /   \     \
#  7      18    28  32  36    48  58  62  72    93

# %%
print("\nAgregar dato")
tree.insert(191)
tree.print_pretty()
# Out:
# Agregar dato
#
#         ____________34_____________
#        /                           \
#     __15_____               ______60_______
#    /         \             /               \
#  _10_       25___         45___         __75___
# /    \     /     \       /     \       /       \
# 5   12    20    30_     40    55_     68_     93_
#  \       /     /   \   /     /   \   /   \   /   \
#  7      18    28  32  36    48  58  62  72  81  191

# %%
print("\nEliminar dato")
tree.delete(58)
tree.print_pretty()
# Out:
# Eliminar dato
#
#         ____________34___________
#        /                         \
#     __15_____               ____60_______
#    /         \             /             \
#  _10_       25___         45___       __75___
# /    \     /     \       /     \     /       \
# 5   12    20    30_     40    55    68_     93_
#  \       /     /   \   /     /     /   \   /   \
#  7      18    28  32  36    48    62  72  81  191

# %%
print("\nBuscar dato")
print(tree.search(10))
tree.print_pretty()
# Out:
# Buscar dato
# True
#
#         ____________34___________
#        /                         \
#     __15_____               ____60_______
#    /         \             /             \
#  _10_       25___         45___       __75___
# /    \     /     \       /     \     /       \
# 5   12    20    30_     40    55    68_     93_
#  \       /     /   \   /     /     /   \   /   \
#  7      18    28  32  36    48    62  72  81  191

# %% [markdown]
# #### **3 - Evaluación de Complejidad**
# ---

# %%
import time

def time_function(func, *args, **kwargs):
    start_time = time.perf_counter()
    result = func(*args, **kwargs)
    end_time = time.perf_counter()
    duration = end_time - start_time
    print(f'Execution time: {duration:.10f} secs')
    return result

# Example usage:
def sample_function(n):
    # Sample function that calculates the sum of numbers from 0 to n-1
    return sum(range(n))

# Time the sample_function execution with argument 1000000
result = time_function(sample_function, 1000000)

# Ejemplo con clase de BST:
# insert_time = time_function(tree.insert, 42)
# Out:
# Execution time: 0.0079007920 secs

# %% [markdown]
# 3.1.a - Instanciar un nuevo objeto **BST** e insertar **5K nodos**. Los valores de dichos nodos deben diseñarse con el objetivo de generar un árbol con la peor topología posible (desde la perspectiva de complejidad temporal).
#
# 3.1.b - Instanciar un nuevo objeto **AVL** e insertar **5K nodos**. Agregar exactamente los valores utilizados en el inciso anterior.

# %%
import sys
import random
from bst import BinarySearchTree
tree = BinarySearchTree()

# Subir límite de recursión
sys.setrecursionlimit(20000)

# Crear 5000 valores aleatorios únicos
valores = random.sample(range(1, 20000), 5000)

# Ordenar para forzar el peor caso (peor topología)
valores.sort()

# Instanciar y poblar el árbol
bst = BinarySearchTree()
for val in valores:
    bst.insert(val)
print("Altura del árbol:", bst.root.data, "->", bst.find_max(bst.root).data)
print("Cantidad de datos:", len(valores))  # Esto imprimirá: 5000
# Crear un nuevo árbol BST o AVL solo con los primeros 100 valores
primeros_100 = valores[:25]  # Usamos los primeros 100 valores

# Si querés ver el BST
bst_100 = BinarySearchTree()
for val in primeros_100:
    bst_100.insert(val)
#print("Primeros 100 nodos del BST:")
bst_100.print_pretty()  #Solo es para comprobar que sean los mismo datos, activarlo solo si quieren ver el arbol y compararlo
# Out:
# Altura del árbol: 5 -> 19999
# Cantidad de datos: 5000
#
# 5
#  \
#  7_
#    \
#   13_
#      \
#     20_
#        \
#       35_
#          \
#         46_
#            \
#           50_
#              \
#             59_
#                \
#               60_
#                  \
#                 75_
#                    \
#                   76_
#                      \
#                     80_
#                        \
#                       86_
#                          \
#                         91_
#                            \
#                           92_
#                              \
#                             102_
#                                 \
#                                114_
#                                    \
#                                   121_
#                                       \
#                                      122_
#                                          \
#                                         128_
# ...

# %%
from avl import AVLTree  # Asegurate de tener importada tu clase AVL

# Crear AVL con los mismos 5000 valores que el BST
avl = AVLTree()
for val in valores:  # 'valores' ya viene de la celda anterior
    avl.insert(val)

print("AVL cargado con los mismos 5000 nodos del BST (balanceado automáticamente).")

# Crear nuevo AVL con los primeros 100 valores (para imprimir bonito)
primeros_100 = valores[:25]
avl_100 = AVLTree()
for val in primeros_100:
    avl_100.insert(val)
avl_100.print_pretty() #Solo es para comprobar que sean los mismo datos, activarlo solo si quieren ver el arbol y compararlo
# Out:
# AVL cargado con los mismos 5000 nodos del BST (balanceado automáticamente).
#
#               ______________102__________
#              /                           \
#       ______59_______               ____128____
#      /               \             /           \
#   __20___         __80___        _121_       _139____
#  /       \       /       \      /     \     /        \
#  7_     46_     75_     91_    114   122   130     _143_
# /  \   /   \   /   \   /   \                      /     \
# 5 13  35  50  60  76  86  92                     140   150

# %% [markdown]
# ##### **Insert()**
#
# Al inicio del inciso *3* se encuentra la función `time_function` junto a un ejemplo de su uso. Esta función permite perfilar el **tiempo** en segundos que toma ejecutar una función y devuelve el resultado con una precisión de diez decimales. Utilice esta función para perfilar el tiempo en los siguientes incisos que lo requieran.
#
# 3.2 - Diseñe una serie de 25 valores que al ser insertados en la estructura (BST o AVL) demanden el peor de los escenarios.
#
# 3.3.a - Programáticamente, realice las 25 operaciones de insert en el BST creado en el inciso *3.1.a*, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.3.b - Programáticamente, realice las mismas 25 operaciones de insert en el AVL creado en el inciso *3.1.b*, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.4 - Utilizando los 25 tiempos registrados para el BST y AVL, calcule el promedio de *insert()* para cada tipo de árbol. Almacene estos dos valores ya que serán utilizados luego.

# %%
import time
import csv
from bst import BinarySearchTree  # Asegurate de tener tu clase BST importada

# Archivo CSV para guardar los resultados
csv_filename = "tiempos_bst.csv"

# Inicializar el archivo solo si es nuevo o se quiere sobrescribir
with open(csv_filename, mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])

# Función para cronometrar tiempo de ejecución de una operación puntual
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"[{nombre_op} - {cantidad_datos} nodos]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por dato: {avg_duration:.10f} segundos")

    # Guardar en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])


bst = BinarySearchTree()

# Cronometrar solo la parte de insert() con 5000 nodos
time_function("insert() BST", len(valores), lambda: [bst.insert(v) for v in valores])

# Crear versión con solo 25 nodos para visualización (sin cronometrar)
primeros_25 = valores[:25]
bst_25 = BinarySearchTree()
for val in primeros_25:
    bst_25.insert(val)

bst_25.print_pretty()  # Descomenta si querés ver el árbol
# Out:
# [insert() BST - 5000 nodos]
#   ➤ Tiempo total: 0.5518268750 segundos
#   ➤ Tiempo promedio por dato: 0.0001103654 segundos
#
# 5
#  \
#  7_
#    \
#   13_
#      \
#     20_
#        \
#       35_
#          \
#         46_
#            \
#           50_
#              \
#             59_
#                \
#               60_
#                  \
#                 75_
#                    \
#                   76_
#                      \
#                     80_
#                        \
#                       86_
#                          \
#                         91_
#                            \
#                           92_
#                              \
#                             102_
#                                 \
#                                114_
#                                    \
#                                   121_
#                                       \
#                                      122_
# ...

# %%
import time
import csv
from avl import AVLTree  # Asegurate de tener importada tu clase AVL

# Archivo CSV para guardar los resultados (mismo archivo del BST)
csv_filename = "tiempos_bst.csv"

# Agregar encabezado solo si el archivo no existe aún (modo 'x')
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass  # No sobrescribir si ya existe

# Función para cronometrar tiempo de ejecución de una operación puntual
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"[{nombre_op} - {cantidad_datos} nodos]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por dato: {avg_duration:.10f} segundos")

    # Guardar en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])


avl = AVLTree()

# Cronometrar solo la parte de insert() con 5000 nodos
time_function("insert() AVL", len(valores), lambda: [avl.insert(v) for v in valores])

# Crear versión con solo 25 nodos para visualización (sin cronometrar)
primeros_25 = valores[:25]
avl_25 = AVLTree()
for val in primeros_25:
    avl_25.insert(val)

avl_25.print_pretty()  # Descomenta si querés ver el árbol
# Out:
# [insert() AVL - 5000 nodos]
#   ➤ Tiempo total: 0.0143060000 segundos
#   ➤ Tiempo promedio por dato: 0.0000028612 segundos
#
#               ______________102__________
#              /                           \
#       ______59_______               ____128____
#      /               \             /           \
#   __20___         __80___        _121_       _139____
#  /       \       /       \      /     \     /        \
#  7_     46_     75_     91_    114   122   130     _143_
# /  \   /   \   /   \   /   \                      /     \
# 5 13  35  50  60  76  86  92                     140   150

# %% [markdown]
# ##### **Search()**
#
# 3.5 - Diseñe una serie de 25 valores que al ser buscados en la estructura (BST o AVL) demanden el peor de los escenarios (no exista).
#
# 3.6.a - Programáticamente, realice las 25 operaciones de search en el BST creado en el inciso 3.1.a, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.6.b - Programáticamente, realice las mismas 25 operaciones de search en el AVL creado en el inciso 3.1.b, midiendo el tiempo de ejecución con la función proporcionada. Guarde los resultados en una lista.
#
# 3.7 - Utilizando los 25 tiempos registrados para el BST y AVL, calcule el promedio de *search()* para cada tipo de árbol. Almacene estos dos valores ya que serán utilizados luego.

# %%
import time
import csv
from bst import BinarySearchTree  # Asegurate de tener tu clase BST importada

# Archivo CSV compartido para guardar los resultados
csv_filename = "tiempos_bst.csv"

# Agregar encabezado si es nuevo
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass

# Función para cronometrar y guardar en CSV
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"\n[{nombre_op} - {cantidad_datos} operaciones]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por operación: {avg_duration:.10f} segundos")

    # Guardar resultado en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])


bst = BinarySearchTree()
for val in valores:
    bst.insert(val)

# === Realizar búsquedas por lote (para estadísticas y CSV) ===

datos_a_buscar = valores[:5000]  # Usamos primeros 1000 como muestra para medir
time_function("search() BST", len(datos_a_buscar), lambda: [bst.search(v) for v in datos_a_buscar])

# === Búsqueda puntual (manual) ===

# Acá podés cambiar el valor que quieras buscar directamente:
valor_manual = 0

resultado = bst.search(valor_manual)
print(f"\n¿{valor_manual} está en el BST? -> {resultado}")
# Out:
# [search() BST - 5000 operaciones]
#   ➤ Tiempo total: 0.6081391670 segundos
#   ➤ Tiempo promedio por operación: 0.0001216278 segundos
#
# ¿0 está en el BST? -> False

# %%
import time
import csv
from avl import AVLTree  # Asegurate de tener tu clase AVL importada

# Archivo CSV compartido para guardar los resultados
csv_filename = "tiempos_bst.csv"  # Mismo archivo compartido

# Agregar encabezado si es nuevo
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass

# Función para cronometrar y guardar en CSV
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"\n[{nombre_op} - {cantidad_datos} operaciones]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por operación: {avg_duration:.10f} segundos")

    # Guardar resultado en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

avl = AVLTree()
for val in valores:
    avl.insert(val)

# === Realizar búsquedas por lote (para estadísticas y CSV) ===

datos_a_buscar = valores[:5000]  # Primeros 1000 valores insertados
time_function("search() AVL", len(datos_a_buscar), lambda: [avl.search(v) for v in datos_a_buscar])

# === Búsqueda puntual (manual) ===

valor_manual = 0 # Cambialo por el valor que querés verificar

resultado = avl.search(valor_manual)
print(f"\n¿{valor_manual} está en el AVL? -> {resultado}")
# Out:
# [search() AVL - 5000 operaciones]
#   ➤ Tiempo total: 0.0020400420 segundos
#   ➤ Tiempo promedio por operación: 0.0000004080 segundos
#
# ¿0 está en el AVL? -> False

# %% [markdown]
# ##### **Insertar 10k nodos**

# %%
import sys
import random
from bst import BinarySearchTree
tree = BinarySearchTree()

# Subir límite de recursión
sys.setrecursionlimit(100000)

# Crear 10000 valores aleatorios únicos
valores = random.sample(range(1, 100000), 10000)

# Ordenar para forzar el peor caso (peor topología)
valores.sort()

# Instanciar y poblar el árbol
bst = BinarySearchTree()
for val in valores:
    bst.insert(val)
print("Altura del árbol:", bst.root.data, "->", bst.find_max(bst.root).data)
print("Cantidad de datos:", len(valores))  # Esto imprimirá: 5000
# Crear un nuevo árbol BST o AVL solo con los primeros 100 valores
primeros_100 = valores[:25]  # Usamos los primeros 100 valores

# Si querés ver el BST
bst_100 = BinarySearchTree()
for val in primeros_100:
    bst_100.insert(val)
#print("Primeros 100 nodos del BST:")
bst_100.print_pretty()  #Solo es para comprobar que sean los mismo datos, activarlo solo si quieren ver el arbol y compararlo
# Out:
# Altura del árbol: 20 -> 99999
# Cantidad de datos: 10000
#
# 20_
#    \
#   23_
#      \
#     29_
#        \
#       32_
#          \
#         55_
#            \
#           56_
#              \
#             66_
#                \
#               78_
#                  \
#                 81_
#                    \
#                   93_
#                      \
#                     102_
#                         \
#                        104_
#                            \
#                           105_
#                               \
#                              157_
#                                  \
#                                 182_
#                                     \
#                                    199_
#                                        \
#                                       212_
#                                           \
#                                          215_
#                                              \
# ...

# %%
from avl import AVLTree  

# Crear AVL con los mismos 10000 valores que el BST
avl = AVLTree()
for val in valores:  # 'valores' ya viene de la celda anterior
    avl.insert(val)

print("AVL cargado con los mismos 10000 nodos del BST (balanceado automáticamente).")

# Crear nuevo AVL con los primeros 100 valores (para imprimir bonito)
primeros_100 = valores[:25]
avl_100 = AVLTree()
for val in primeros_100:
    avl_100.insert(val)
avl_100.print_pretty() #Solo es para comprobar que sean los mismo datos, activarlo solo si quieren ver el arbol y compararlo
# Out:
# AVL cargado con los mismos 10000 nodos del BST (balanceado automáticamente).
#
#                 ___________________199__________
#                /                                \
#         ______78________                   ____253____
#        /                \                 /           \
#     __32___         ___104____          _215_       _260____
#    /       \       /          \        /     \     /        \
#   23_     56_     93_       _157_     212   249   259     _264_
#  /   \   /   \   /   \     /     \                       /     \
# 20  29  55  66  81  102   105   182                     261   267

# %% [markdown]
# ##### **Insert()**

# %%
import time
import csv
from bst import BinarySearchTree  # Asegurate de tener tu clase BST importada

# Archivo CSV para guardar los resultados
csv_filename = "tiempos_bst.csv"

# Inicializar el archivo solo si es nuevo o se quiere sobrescribir
with open(csv_filename, mode='a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])

# Función para cronometrar tiempo de ejecución de una operación puntual
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"[{nombre_op} - {cantidad_datos} nodos]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por dato: {avg_duration:.10f} segundos")

    # Guardar en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

bst = BinarySearchTree()

# Cronometrar solo la parte de insert() con 5000 nodos
time_function("insert() BST", len(valores), lambda: [bst.insert(v) for v in valores])

# Crear versión con solo 25 nodos para visualización (sin cronometrar)
primeros_25 = valores[:25]
bst_25 = BinarySearchTree()
for val in primeros_25:
    bst_25.insert(val)

bst_25.print_pretty()  # Descomenta si querés ver el árbol
# Out:
# [insert() BST - 10000 nodos]
#   ➤ Tiempo total: 2.2366440830 segundos
#   ➤ Tiempo promedio por dato: 0.0002236644 segundos
#
# 20_
#    \
#   23_
#      \
#     29_
#        \
#       32_
#          \
#         55_
#            \
#           56_
#              \
#             66_
#                \
#               78_
#                  \
#                 81_
#                    \
#                   93_
#                      \
#                     102_
#                         \
#                        104_
#                            \
#                           105_
#                               \
#                              157_
#                                  \
#                                 182_
#                                     \
#                                    199_
#                                        \
#                                       212_
#                                           \
#                                          215_
# ...

# %%
import time
import csv
from avl import AVLTree  # Asegurate de tener importada tu clase AVL

# Archivo CSV para guardar los resultados (mismo archivo del BST)
csv_filename = "tiempos_bst.csv"

# Agregar encabezado solo si el archivo no existe aún (modo 'x')
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass  # No sobrescribir si ya existe

# Función para cronometrar tiempo de ejecución de una operación puntual
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"[{nombre_op} - {cantidad_datos} nodos]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por dato: {avg_duration:.10f} segundos")

    # Guardar en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

avl = AVLTree()

# Cronometrar solo la parte de insert() con 5000 nodos
time_function("insert() AVL", len(valores), lambda: [avl.insert(v) for v in valores])

# Crear versión con solo 25 nodos para visualización (sin cronometrar)
primeros_25 = valores[:25]
avl_25 = AVLTree()
for val in primeros_25:
    avl_25.insert(val)

avl_25.print_pretty()  # Descomenta si querés ver el árbol
# Out:
# [insert() AVL - 10000 nodos]
#   ➤ Tiempo total: 0.0316591670 segundos
#   ➤ Tiempo promedio por dato: 0.0000031659 segundos
#
#                 ___________________199__________
#                /                                \
#         ______78________                   ____253____
#        /                \                 /           \
#     __32___         ___104____          _215_       _260____
#    /       \       /          \        /     \     /        \
#   23_     56_     93_       _157_     212   249   259     _264_
#  /   \   /   \   /   \     /     \                       /     \
# 20  29  55  66  81  102   105   182                     261   267

# %% [markdown]
# ##### **Search()**

# %%
import time
import csv
from bst import BinarySearchTree  # Asegurate de tener tu clase BST importada

# Archivo CSV compartido para guardar los resultados
csv_filename = "tiempos_bst.csv"

# Agregar encabezado si es nuevo
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass

# Función para cronometrar y guardar en CSV
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"\n[{nombre_op} - {cantidad_datos} operaciones]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por operación: {avg_duration:.10f} segundos")

    # Guardar resultado en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])


bst = BinarySearchTree()
for val in valores:
    bst.insert(val)

# === Realizar búsquedas por lote (para estadísticas y CSV) ===

datos_a_buscar = valores[:10000] 
time_function("search() BST", len(datos_a_buscar), lambda: [bst.search(v) for v in datos_a_buscar])

# === Búsqueda puntual (manual) ===

# Acá podés cambiar el valor que quieras buscar directamente:
valor_manual = 0

resultado = bst.search(valor_manual)
print(f"\n¿{valor_manual} está en el BST? -> {resultado}")
# Out:
# [search() BST - 10000 operaciones]
#   ➤ Tiempo total: 2.4425776660 segundos
#   ➤ Tiempo promedio por operación: 0.0002442578 segundos
#
# ¿0 está en el BST? -> False

# %%
import time
import csv
from avl import AVLTree  # Asegurate de tener tu clase AVL importada

# Archivo CSV compartido para guardar los resultados
csv_filename = "tiempos_bst.csv"  # Mismo archivo compartido

# Agregar encabezado si es nuevo
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass

# Función para cronometrar y guardar en CSV
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"\n[{nombre_op} - {cantidad_datos} operaciones]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por operación: {avg_duration:.10f} segundos")

    # Guardar resultado en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

avl = AVLTree()
for val in valores:
    avl.insert(val)

# === Realizar búsquedas por lote (para estadísticas y CSV) ===

datos_a_buscar = valores[:10000]  # Primeros 10000 valores insertados
time_function("search() AVL", len(datos_a_buscar), lambda: [avl.search(v) for v in datos_a_buscar])

# === Búsqueda puntual (manual) ===

valor_manual = 0 # Cambialo por el valor que querés verificar

resultado = avl.search(valor_manual)
print(f"\n¿{valor_manual} está en el AVL? -> {resultado}")
# Out:
# [search() AVL - 10000 operaciones]
#   ➤ Tiempo total: 0.0044200420 segundos
#   ➤ Tiempo promedio por operación: 0.0000004420 segundos
#
# ¿0 está en el AVL? -> False

# %% [markdown]
# ##### **Insertar 25k nodos**

# %%
import sys
import random
from bst import BinarySearchTree

# Subir límite de recursión porque el árbol estará muy desbalanceado
sys.setrecursionlimit(100000)

# Crear 25,000 valores aleatorios únicos
valores = random.sample(range(1, 1000000), 25000)

# Ordenar para forzar el peor caso (el árbol será una lista enlazada)
valores.sort()

# Instanciar y poblar el árbol BST con los 25,000 valores
bst = BinarySearchTree()
for val in valores:
    bst.insert(val)

# Mostrar datos generales
print("Altura del árbol:", bst.root.data, "->", bst.find_max(bst.root).data)
print("Cantidad de datos:", len(valores))  # Esto imprimirá: 25000

# Crear una versión pequeña del árbol con los primeros 25 nodos (para visualización)
primeros_25 = valores[:25]
bst_25 = BinarySearchTree()
for val in primeros_25:
    bst_25.insert(val)

# Visualizar el árbol reducido
bst_25.print_pretty()  # Activá si querés ver cómo se ve estructuralmente
# Out:
# Altura del árbol: 15 -> 999969
# Cantidad de datos: 25000
#
# 15_
#    \
#   57_
#      \
#     107_
#         \
#        122_
#            \
#           181_
#               \
#              191_
#                  \
#                 219_
#                     \
#                    239_
#                        \
#                       373_
#                           \
#                          395_
#                              \
#                             523_
#                                 \
#                                565_
#                                    \
#                                   586_
#                                       \
#                                      598_
#                                          \
#                                         618_
#                                             \
#                                            645_
#                                                \
# ...

# %%
from avl import AVLTree  

# Crear AVL con los mismos 25000 valores que el BST
avl = AVLTree()
for val in valores:  # 'valores' ya viene de la celda anterior
    avl.insert(val)

print("AVL cargado con los mismos 25000 nodos del BST (balanceado automáticamente).")

# Crear nuevo AVL con los primeros 100 valores (para imprimir bonito)
primeros_100 = valores[:25]
avl_100 = AVLTree()
for val in primeros_100:
    avl_100.insert(val)
avl_100.print_pretty() #Solo es para comprobar que sean los mismo datos, activarlo solo si quieren ver el arbol y compararlo
# Out:
# AVL cargado con los mismos 25000 nodos del BST (balanceado automáticamente).
#
#                      ______________________645__________
#                     /                                   \
#          __________239__________                   ____739____
#         /                       \                 /           \
#     ___122____             ____565____          _720_       _834____
#    /          \           /           \        /     \     /        \
#   57_       _191_       _395_       _598_     667   726   818     _874_
#  /   \     /     \     /     \     /     \                       /     \
# 15  107   181   219   373   523   586   618                     835   880

# %% [markdown]
# ##### **Insert()**

# %%
import time
import csv
from bst import BinarySearchTree  # Asegurate de tener tu clase BST importada

# Archivo CSV para guardar los resultados
csv_filename = "tiempos_bst.csv"

# Inicializar el archivo solo si es nuevo o se quiere sobrescribir
with open(csv_filename, mode='a', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])

# Función para cronometrar tiempo de ejecución de una operación puntual
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"[{nombre_op} - {cantidad_datos} nodos]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por dato: {avg_duration:.10f} segundos")

    # Guardar en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

bst = BinarySearchTree()

# Cronometrar solo la parte de insert() con 25000 nodos
time_function("insert() BST", len(valores), lambda: [bst.insert(v) for v in valores])

# Crear versión con solo 25 nodos para visualización (sin cronometrar)
primeros_25 = valores[:25]
bst_25 = BinarySearchTree()
for val in primeros_25:
    bst_25.insert(val)

bst_25.print_pretty()  # Descomenta si querés ver el árbol
# Out:
# [insert() BST - 25000 nodos]
#   ➤ Tiempo total: 14.0813643340 segundos
#   ➤ Tiempo promedio por dato: 0.0005632546 segundos
#
# 15_
#    \
#   57_
#      \
#     107_
#         \
#        122_
#            \
#           181_
#               \
#              191_
#                  \
#                 219_
#                     \
#                    239_
#                        \
#                       373_
#                           \
#                          395_
#                              \
#                             523_
#                                 \
#                                565_
#                                    \
#                                   586_
#                                       \
#                                      598_
#                                          \
#                                         618_
#                                             \
#                                            645_
# ...

# %%
import time
import csv
from avl import AVLTree  # Asegurate de tener importada tu clase AVL

# Archivo CSV para guardar los resultados (mismo archivo del BST)
csv_filename = "tiempos_bst.csv"

# Agregar encabezado solo si el archivo no existe aún (modo 'x')
try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass  # No sobrescribir si ya existe

# Función para cronometrar tiempo de ejecución de una operación puntual
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"[{nombre_op} - {cantidad_datos} nodos]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por dato: {avg_duration:.10f} segundos")

    # Guardar en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

avl = AVLTree()

# Cronometrar solo la parte de insert() con 25000 nodos
time_function("insert() AVL", len(valores), lambda: [avl.insert(v) for v in valores])

# Crear versión con solo 25 nodos para visualización (sin cronometrar)
primeros_25 = valores[:25]
avl_25 = AVLTree()
for val in primeros_25:
    avl_25.insert(val)

avl_25.print_pretty()  # Descomenta si querés ver el árbol
# Out:
# [insert() AVL - 25000 nodos]
#   ➤ Tiempo total: 0.0992256250 segundos
#   ➤ Tiempo promedio por dato: 0.0000039690 segundos
#
#                      ______________________645__________
#                     /                                   \
#          __________239__________                   ____739____
#         /                       \                 /           \
#     ___122____             ____565____          _720_       _834____
#    /          \           /           \        /     \     /        \
#   57_       _191_       _395_       _598_     667   726   818     _874_
#  /   \     /     \     /     \     /     \                       /     \
# 15  107   181   219   373   523   586   618                     835   880

# %% [markdown]
# ##### **search()**

# %%
import time
import csv
from bst import BinarySearchTree

csv_filename = "tiempos_bst.csv"

try:
    with open(csv_filename, mode='x', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Operacion", "Cantidad de Datos", "Tiempo Total (s)", "Tiempo Promedio por Dato (s)"])
except FileExistsError:
    pass

def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"\n[{nombre_op} - {cantidad_datos} operaciones]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por operación: {avg_duration:.10f} segundos")

    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])


# Suponiendo que 'valores' ya está definido con 25,000 datos
bst = BinarySearchTree()
for val in valores:
    bst.insert(val)

# ✅ Buscar todos los valores correctamente
datos_a_buscar = valores[:]  # o simplemente datos_a_buscar = valores
time_function("search() BST", len(datos_a_buscar), lambda: [bst.search(v) for v in datos_a_buscar])

# Búsqueda manual
valor_manual = 0
resultado = bst.search(valor_manual)
print(f"\n¿{valor_manual} está en el BST? -> {resultado}")
# Out:
# [search() BST - 25000 operaciones]
#   ➤ Tiempo total: 15.5673318340 segundos
#   ➤ Tiempo promedio por operación: 0.0006226933 segundos
#
# ¿0 está en el BST? -> False

# %%
import time
import csv
from avl import AVLTree  # Asegurate de tener tu clase AVL importada

# Archivo CSV compartido para guardar los resultados
csv_filename = "tiempos_bst.csv"  # Mismo archivo compartido

# Agregar encabezado si es nuevo
try:
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)

except FileExistsError:
    pass

# Función para cronometrar y guardar en CSV
def time_function(nombre_op, cantidad_datos, func):
    start_time = time.perf_counter()
    func()
    end_time = time.perf_counter()
    total_duration = end_time - start_time
    avg_duration = total_duration / cantidad_datos if cantidad_datos > 0 else 0

    print(f"\n[{nombre_op} - {cantidad_datos} operaciones]")
    print(f"  ➤ Tiempo total: {total_duration:.10f} segundos")
    print(f"  ➤ Tiempo promedio por operación: {avg_duration:.10f} segundos")

    # Guardar resultado en CSV
    with open(csv_filename, mode='a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow([nombre_op, cantidad_datos, total_duration, avg_duration])

avl = AVLTree()
for val in valores:
    avl.insert(val)

# === Realizar búsquedas por lote (para estadísticas y CSV) ===

datos_a_buscar = valores[:25000]  # Primeros 10000 valores insertados
time_function("search() AVL", len(datos_a_buscar), lambda: [avl.search(v) for v in datos_a_buscar])

# === Búsqueda puntual (manual) ===

valor_manual = 0 # Cambialo por el valor que querés verificar

resultado = avl.search(valor_manual)
print(f"\n¿{valor_manual} está en el AVL? -> {resultado}")
# Out:
# [search() AVL - 25000 operaciones]
#   ➤ Tiempo total: 0.0119100830 segundos
#   ➤ Tiempo promedio por operación: 0.0000004764 segundos
#
# ¿0 está en el AVL? -> False

# %% [markdown]
# #### **4 - Gráfica**
# ---
#
# Una vez realizados todos los puntos del inciso *3* correctamente, debería tener la siguiente información basada en tiempos promedio tanto para el **BST** como para el **AVL**:
#
# |Operación | N = 5K   | N = 10K  | N = 25K  |
# |----------|----------|----------|----------|
# | Insert() | x secs   | x secs   | x secs   |
# | Search() | x secs   | x secs   | x secs   |
#
# Importante: recuerde mantener la precisión de diez decimales en los registros de tiempo.
#
# 4.1 - Programáticamente unificar los resultados en el formato que necesite para una ejecución automática de los incisos siguientes.
#
# 4.2 - Crear una gráfica que ilustre la complejidad de la operación de *Insert()* tanto para BST como para AVL. Considerar que:
# * Debe ser una única gráfica que superponga los resultados del BST y el AVL
# * Las funciones de complejidad resultantes deben identificar correctamente el tipo de árbol al que pertenece
# * Debe graficar las funciones de complejidad con un color distinto
#
# 4.3 - Crear una gráfica que ilustre la complejidad de la operación de *Search()* tanto para BST como para AVL. Tener presente las mismas consideraciones que en el inciso *4.2*.
#
# Recuerde que el objetivo es evidenciar claramente que la complejidad de las estructuras corresponden a la teoría, o sea:
# * Binary Search Tree - $O(n)$
# * AVL Tree - $O(log_{2}n)$

# %%
import csv
import matplotlib.pyplot as plt

# === Leer datos del CSV ===
archivo_csv = "tiempos_bst.csv"

insert_data = {
    "insert() BST": [],
    "insert() AVL": []
}

search_data = {
    "search() BST": [],
    "search() AVL": []
}

with open(archivo_csv, newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        if row["Operacion"] == "Operacion":
            continue
        op = row["Operacion"]
        cantidad = int(row["Cantidad de Datos"])
        tiempo_promedio = float(row["Tiempo Promedio por Dato (s)"])

        if op in insert_data:
            insert_data[op].append((cantidad, tiempo_promedio))
        elif op in search_data:
            search_data[op].append((cantidad, tiempo_promedio))

# Ordenar los puntos por cantidad
for grupo in (insert_data, search_data):
    for key in grupo:
        grupo[key].sort()

xticks_custom = [1000, 5000, 10000, 15000, 20000, 25000]

# === GRÁFICO 1: insert() promedio ===
plt.figure(figsize=(10, 6))

# BST (lineal)
x_bst = [p[0] for p in insert_data["insert() BST"]]
y_bst = [p[1] for p in insert_data["insert() BST"]]
plt.plot(x_bst, y_bst, marker='o', label="insert() BST")

# AVL (logarítmico)
x_avl = [p[0] for p in insert_data["insert() AVL"]]
y_avl = [p[1] for p in insert_data["insert() AVL"]]
plt.plot(x_avl, y_avl, marker='o', label="insert() AVL (log scale)", linestyle='--')

plt.yscale("log")
plt.title("Tiempo promedio de insert() - BST vs AVL")
plt.xlabel("Cantidad de Datos")
plt.ylabel("Tiempo Promedio por Dato (segundos)")
plt.xticks(xticks_custom)
plt.legend()
plt.grid(True, which="both", linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig("insert_promedio_log_mix.png")
plt.show()

# === GRÁFICO 2: search() promedio ===
plt.figure(figsize=(10, 6))

# BST (lineal)
x_bst = [p[0] for p in search_data["search() BST"]]
y_bst = [p[1] for p in search_data["search() BST"]]
plt.plot(x_bst, y_bst, marker='o', label="search() BST")

# AVL (logarítmico)
x_avl = [p[0] for p in search_data["search() AVL"]]
y_avl = [p[1] for p in search_data["search() AVL"]]
plt.plot(x_avl, y_avl, marker='o', label="search() AVL (log scale)", linestyle='--')

plt.yscale("log")
plt.title("Tiempo promedio de search() - BST vs AVL")
plt.xlabel("Cantidad de Datos")
plt.ylabel("Tiempo Promedio por Dato (segundos)")
plt.xticks(xticks_custom)
plt.legend()
plt.grid(True, which="both", linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.savefig("search_promedio_log_mix.png")
plt.show()

# %% [markdown]
# ---

# %%
#EL AVL puede parecer lineal y que va en el mismo numero en el eje y,
#pero si se ve en escala logaritmica, se nota que es mucho mas eficiente
